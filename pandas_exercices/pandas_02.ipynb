# %%
import pandas as pd
import numpy as np
import kagglehub

# %%
path = kagglehub.dataset_download("kanchana1990/airbnb-las-vegas-listings")
print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/michallispashidis/.cache/kagglehub/datasets/kanchana1990/airbnb-las-vegas-listings/versions/1

# %%
dataframe = pd.read_csv("/Users/michallispashidis/.cache/kagglehub/datasets/kanchana1990/airbnb-las-vegas-listings/versions/1/las_vegas_airbnb_data.csv")

# %%
my_dict = {"col1":[1,2,3,4], "col2": [4,5,6,7], "col3": [8,9,10,11]}
# define dataframe index
my_a = ['a','b','c','d']

# %%
df = pd.DataFrame(data=my_dict, index=my_a)

# %%
df
# Out:
#    col1  col2  col3
# a     1     4     8
# b     2     5     9
# c     3     6    10
# d     4     7    11

# %%
df.iloc[0:3]
# Out:
#    col1  col2  col3
# a     1     4     8
# b     2     5     9
# c     3     6    10

# %%
df.loc['c']
# Out:
# col1     3
# col2     6
# col3    10
# Name: c, dtype: int64

# %%
dict2 = {"col1":[1,2,3,4], "col2": pd.Series([4,6],index=[0,1])}
df2 = pd.DataFrame(data=dict2, index=[0,1,2,3])

# %%
df2
# Out:
#    col1  col2
# 0     1   4.0
# 1     2   6.0
# 2     3   NaN
# 3     4   NaN

# %%
df.head()
# Out:
#    col1  col2  col3
# a     1     4     8
# b     2     5     9
# c     3     6    10
# d     4     7    11

# %%
dataframe.head()
# Out:
#                roomType  stars                           address  \
# 0          Entire condo   4.54  Las Vegas, Nevada, United States
# 1    Entire rental unit   4.39  Las Vegas, Nevada, United States
# 2    Entire guest suite    NaN  Las Vegas, Nevada, United States
# 3          Entire condo    NaN  Las Vegas, Nevada, United States
# 4  Private room in home   4.51  Las Vegas, Nevada, United States
#
#    numberOfGuests primaryHost/smartName  price  \
# 0               4                  Doug    NaN
# 1               4                  Doug    NaN
# 2               4            Aaron&Tina    NaN
# 3               6            Aaron&Tina    NaN
# 4               2                  Brad    NaN
#
#                                  firstReviewComments  firstReviewRating
# 0  Overall, I had a good experience. The only dow...                4.0
# 1  I stayed an extra night. That should sum it up...                5.0
# ...

# %%
dataframe.describe()
# Out:
#             stars  numberOfGuests  price  firstReviewRating
# count  723.000000     1000.000000    0.0         795.000000
# mean     4.836528        7.070000    NaN           4.794969
# std      0.167377        3.959644    NaN           0.661633
# min      3.670000        1.000000    NaN           1.000000
# 25%      4.770000        4.000000    NaN           5.000000
# 50%      4.870000        6.000000    NaN           5.000000
# 75%      4.960000        8.000000    NaN           5.000000
# max      5.000000       16.000000    NaN           5.000000

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   roomType               1000 non-null   object
#  1   stars                  723 non-null    float64
#  2   address                1000 non-null   object
#  3   numberOfGuests         1000 non-null   int64
#  4   primaryHost/smartName  1000 non-null   object
#  5   price                  0 non-null      float64
#  6   firstReviewComments    795 non-null    object
#  7   firstReviewRating      795 non-null    float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 62.6+ KB

# %%
df = dataframe[["stars","numberOfGuests"]]

# %%
df[0:6]
# Out:
#    stars  numberOfGuests
# 0   4.54               4
# 1   4.39               4
# 2    NaN               4
# 3    NaN               6
# 4   4.51               2
# 5   4.96              15

# %%
type(df["stars"])
# Out:
# pandas.core.series.Series

# %%
dataframe["new_col"] = dataframe["numberOfGuests"] + dataframe["firstReviewRating"]

# %%
dataframe
# Out:
#                  roomType  stars  \
# 0            Entire condo   4.54
# 1      Entire rental unit   4.39
# 2      Entire guest suite    NaN
# 3            Entire condo    NaN
# 4    Private room in home   4.51
# ..                    ...    ...
# 995          Entire condo   5.00
# 996           Entire home   4.77
# 997          Entire condo   4.93
# 998           Entire home   5.00
# 999         Room in hotel    NaN
#
#                                               address  numberOfGuests  \
# 0                    Las Vegas, Nevada, United States               4
# 1                    Las Vegas, Nevada, United States               4
# 2                    Las Vegas, Nevada, United States               4
# 3                    Las Vegas, Nevada, United States               6
# 4                    Las Vegas, Nevada, United States               2
# ..                                                ...             ...
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   roomType               1000 non-null   object
#  1   stars                  723 non-null    float64
#  2   address                1000 non-null   object
#  3   numberOfGuests         1000 non-null   int64
#  4   primaryHost/smartName  1000 non-null   object
#  5   price                  0 non-null      float64
#  6   firstReviewComments    795 non-null    object
#  7   firstReviewRating      795 non-null    float64
#  8   new_col                795 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 70.4+ KB

# %%
s = sum(df["numberOfGuests"])

# %%
s
# Out:
# 7070

# %%
dataframe.head()
# Out:
#                roomType  stars                           address  \
# 0          Entire condo   4.54  Las Vegas, Nevada, United States
# 1    Entire rental unit   4.39  Las Vegas, Nevada, United States
# 2    Entire guest suite    NaN  Las Vegas, Nevada, United States
# 3          Entire condo    NaN  Las Vegas, Nevada, United States
# 4  Private room in home   4.51  Las Vegas, Nevada, United States
#
#    numberOfGuests primaryHost/smartName  price  \
# 0               4                  Doug    NaN
# 1               4                  Doug    NaN
# 2               4            Aaron&Tina    NaN
# 3               6            Aaron&Tina    NaN
# 4               2                  Brad    NaN
#
#                                  firstReviewComments  firstReviewRating  \
# 0  Overall, I had a good experience. The only dow...                4.0
# 1  I stayed an extra night. That should sum it up...                5.0
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   roomType               1000 non-null   object
#  1   stars                  723 non-null    float64
#  2   address                1000 non-null   object
#  3   numberOfGuests         1000 non-null   int64
#  4   primaryHost/smartName  1000 non-null   object
#  5   price                  0 non-null      float64
#  6   firstReviewComments    795 non-null    object
#  7   firstReviewRating      795 non-null    float64
#  8   new_col                795 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 70.4+ KB

# %%
dataframe.drop("price", axis=1, inplace=True)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   roomType               1000 non-null   object
#  1   stars                  723 non-null    float64
#  2   address                1000 non-null   object
#  3   numberOfGuests         1000 non-null   int64
#  4   primaryHost/smartName  1000 non-null   object
#  5   firstReviewComments    795 non-null    object
#  6   firstReviewRating      795 non-null    float64
#  7   new_col                795 non-null    float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 62.6+ KB

# %%
dataframe
# Out:
#                  roomType  stars  \
# 0            Entire condo   4.54
# 1      Entire rental unit   4.39
# 2      Entire guest suite    NaN
# 3            Entire condo    NaN
# 4    Private room in home   4.51
# ..                    ...    ...
# 995          Entire condo   5.00
# 996           Entire home   4.77
# 997          Entire condo   4.93
# 998           Entire home   5.00
# 999         Room in hotel    NaN
#
#                                               address  numberOfGuests  \
# 0                    Las Vegas, Nevada, United States               4
# 1                    Las Vegas, Nevada, United States               4
# 2                    Las Vegas, Nevada, United States               4
# 3                    Las Vegas, Nevada, United States               6
# 4                    Las Vegas, Nevada, United States               2
# ..                                                ...             ...
# ...

# %%
dataframe.drop(0, axis=0, inplace=True)

# %%
dataframe
# Out:
#                  roomType  stars  \
# 1      Entire rental unit   4.39
# 2      Entire guest suite    NaN
# 3            Entire condo    NaN
# 4    Private room in home   4.51
# 5             Entire home   4.96
# ..                    ...    ...
# 995          Entire condo   5.00
# 996           Entire home   4.77
# 997          Entire condo   4.93
# 998           Entire home   5.00
# 999         Room in hotel    NaN
#
#                                               address  numberOfGuests  \
# 1                    Las Vegas, Nevada, United States               4
# 2                    Las Vegas, Nevada, United States               4
# 3                    Las Vegas, Nevada, United States               6
# 4                    Las Vegas, Nevada, United States               2
# 5                    Las Vegas, Nevada, United States              15
# ..                                                ...             ...
# ...

# %%
df.head(1)
# Out:
#    stars  numberOfGuests
# 0   4.54               4

# %%
dataframe.head()
# Out:
#                roomType  stars                           address  \
# 1    Entire rental unit   4.39  Las Vegas, Nevada, United States
# 2    Entire guest suite    NaN  Las Vegas, Nevada, United States
# 3          Entire condo    NaN  Las Vegas, Nevada, United States
# 4  Private room in home   4.51  Las Vegas, Nevada, United States
# 5           Entire home   4.96  Las Vegas, Nevada, United States
#
#    numberOfGuests primaryHost/smartName  \
# 1               4                  Doug
# 2               4            Aaron&Tina
# 3               6            Aaron&Tina
# 4               2                  Brad
# 5              15                 Simon
#
#                                  firstReviewComments  firstReviewRating  \
# 1  I stayed an extra night. That should sum it up...                5.0
# 2  These days things are so impersonable but she ...                5.0
# 3  Great response time from owner. Could message ...                5.0
# ...

# %%
dataframe.drop(1, axis=0, inplace=True)

# %%
dataframe.head()
# Out:
#                roomType  stars                           address  \
# 2    Entire guest suite    NaN  Las Vegas, Nevada, United States
# 3          Entire condo    NaN  Las Vegas, Nevada, United States
# 4  Private room in home   4.51  Las Vegas, Nevada, United States
# 5           Entire home   4.96  Las Vegas, Nevada, United States
# 6         Room in hotel    NaN  Las Vegas, Nevada, United States
#
#    numberOfGuests primaryHost/smartName  \
# 2               4            Aaron&Tina
# 3               6            Aaron&Tina
# 4               2                  Brad
# 5              15                 Simon
# 6               4             Suiteness
#
#                                  firstReviewComments  firstReviewRating  \
# 2  These days things are so impersonable but she ...                5.0
# 3  Great response time from owner. Could message ...                5.0
# 4  good group of guys in the house. quiet clean a...                5.0
# ...

# %%
dataframe[0:5]
# Out:
#                roomType  stars                           address  \
# 2    Entire guest suite    NaN  Las Vegas, Nevada, United States
# 3          Entire condo    NaN  Las Vegas, Nevada, United States
# 4  Private room in home   4.51  Las Vegas, Nevada, United States
# 5           Entire home   4.96  Las Vegas, Nevada, United States
# 6         Room in hotel    NaN  Las Vegas, Nevada, United States
#
#    numberOfGuests primaryHost/smartName  \
# 2               4            Aaron&Tina
# 3               6            Aaron&Tina
# 4               2                  Brad
# 5              15                 Simon
# 6               4             Suiteness
#
#                                  firstReviewComments  firstReviewRating  \
# 2  These days things are so impersonable but she ...                5.0
# 3  Great response time from owner. Could message ...                5.0
# 4  good group of guys in the house. quiet clean a...                5.0
# ...

# %%
dataframe.loc[[2,3,4],["roomType","stars","address","numberOfGuests"]]
# Out:
#                roomType  stars                           address  \
# 2    Entire guest suite    NaN  Las Vegas, Nevada, United States
# 3          Entire condo    NaN  Las Vegas, Nevada, United States
# 4  Private room in home   4.51  Las Vegas, Nevada, United States
#
#    numberOfGuests
# 2               4
# 3               6
# 4               2

# %%
dataframe.loc[[2,3,4,5,6],["roomType","stars","address","numberOfGuests"]]
# Out:
#                roomType  stars                           address  \
# 2    Entire guest suite    NaN  Las Vegas, Nevada, United States
# 3          Entire condo    NaN  Las Vegas, Nevada, United States
# 4  Private room in home   4.51  Las Vegas, Nevada, United States
# 5           Entire home   4.96  Las Vegas, Nevada, United States
# 6         Room in hotel    NaN  Las Vegas, Nevada, United States
#
#    numberOfGuests
# 2               4
# 3               6
# 4               2
# 5              15
# 6               4

# %%
dataframe[dataframe["numberOfGuests"]<4].head()
# Out:
#                  roomType  stars                           address  \
# 4    Private room in home   4.51  Las Vegas, Nevada, United States
# 178  Private room in home   5.00  Las Vegas, Nevada, United States
# 221             Camper/RV   4.89  Las Vegas, Nevada, United States
# 223    Entire guest suite   4.60  Las Vegas, Nevada, United States
# 240         Room in hotel    NaN  Las Vegas, Nevada, United States
#
#      numberOfGuests primaryHost/smartName  \
# 4                 2                  Brad
# 178               2                Carlos
# 221               2                  Brad
# 223               2                Hernan
# 240               3             Suiteness
#
#                                    firstReviewComments  firstReviewRating  \
# 4    good group of guys in the house. quiet clean a...                5.0
# 178  Was in a quiet neighborhood, host was extremel...                5.0
# 221                                    Friendly people                5.0
# ...

# %%
dataframe[dataframe["primaryHost/smartName"]=="Brad"].head()
# Out:
#                  roomType  stars                           address  \
# 4    Private room in home   4.51  Las Vegas, Nevada, United States
# 221             Camper/RV   4.89  Las Vegas, Nevada, United States
#
#      numberOfGuests primaryHost/smartName  \
# 4                 2                  Brad
# 221               2                  Brad
#
#                                    firstReviewComments  firstReviewRating  \
# 4    good group of guys in the house. quiet clean a...                5.0
# 221                                    Friendly people                5.0
#
#      new_col
# 4        7.0
# 221      7.0

# %%
df = dataframe

# %%
df[(df["numberOfGuests"]==2) & (df["firstReviewRating"]<5)]
# Out:
#                  roomType  stars                                 address  \
# 577  Private room in home   4.93        Las Vegas, Nevada, United States
# 609          Entire condo   4.55        Las Vegas, Nevada, United States
# 637    Entire guest suite   4.81        Las Vegas, Nevada, United States
# 643           Entire home   4.81        Las Vegas, Nevada, United States
# 646           Entire home   4.87        Las Vegas, Nevada, United States
# 647           Entire home   4.61        Las Vegas, Nevada, United States
# 658          Entire villa   4.86        Las Vegas, Nevada, United States
# 719    Entire guest suite   4.91        Las Vegas, Nevada, United States
# 793          Entire condo   4.00        Las Vegas, Nevada, United States
# 807     Entire guesthouse   4.77  North Las Vegas, Nevada, United States
# 822  Private room in home   4.97        Las Vegas, Nevada, United States
# 826    Entire rental unit   4.87        Las Vegas, Nevada, United States
# ...

# %%
df.head()
# Out:
#                roomType  stars                           address  \
# 2    Entire guest suite    NaN  Las Vegas, Nevada, United States
# 3          Entire condo    NaN  Las Vegas, Nevada, United States
# 4  Private room in home   4.51  Las Vegas, Nevada, United States
# 5           Entire home   4.96  Las Vegas, Nevada, United States
# 6         Room in hotel    NaN  Las Vegas, Nevada, United States
#
#    numberOfGuests primaryHost/smartName  \
# 2               4            Aaron&Tina
# 3               6            Aaron&Tina
# 4               2                  Brad
# 5              15                 Simon
# 6               4             Suiteness
#
#                                  firstReviewComments  firstReviewRating  \
# 2  These days things are so impersonable but she ...                5.0
# 3  Great response time from owner. Could message ...                5.0
# 4  good group of guys in the house. quiet clean a...                5.0
# ...

# %%
df.reset_index()
# Out:
#      index              roomType  stars  \
# 0        2    Entire guest suite    NaN
# 1        3          Entire condo    NaN
# 2        4  Private room in home   4.51
# 3        5           Entire home   4.96
# 4        6         Room in hotel    NaN
# ..     ...                   ...    ...
# 993    995          Entire condo   5.00
# 994    996           Entire home   4.77
# 995    997          Entire condo   4.93
# 996    998           Entire home   5.00
# 997    999         Room in hotel    NaN
#
#                                               address  numberOfGuests  \
# 0                    Las Vegas, Nevada, United States               4
# 1                    Las Vegas, Nevada, United States               6
# 2                    Las Vegas, Nevada, United States               2
# 3                    Las Vegas, Nevada, United States              15
# 4                    Las Vegas, Nevada, United States               4
# ...

# %%
df.head()
# Out:
#                roomType  stars                           address  \
# 2    Entire guest suite    NaN  Las Vegas, Nevada, United States
# 3          Entire condo    NaN  Las Vegas, Nevada, United States
# 4  Private room in home   4.51  Las Vegas, Nevada, United States
# 5           Entire home   4.96  Las Vegas, Nevada, United States
# 6         Room in hotel    NaN  Las Vegas, Nevada, United States
#
#    numberOfGuests primaryHost/smartName  \
# 2               4            Aaron&Tina
# 3               6            Aaron&Tina
# 4               2                  Brad
# 5              15                 Simon
# 6               4             Suiteness
#
#                                  firstReviewComments  firstReviewRating  \
# 2  These days things are so impersonable but she ...                5.0
# 3  Great response time from owner. Could message ...                5.0
# 4  good group of guys in the house. quiet clean a...                5.0
# ...

# %%
df[0:11]
# Out:
#                   roomType  stars                           address  \
# 2       Entire guest suite    NaN  Las Vegas, Nevada, United States
# 3             Entire condo    NaN  Las Vegas, Nevada, United States
# 4     Private room in home   4.51  Las Vegas, Nevada, United States
# 5              Entire home   4.96  Las Vegas, Nevada, United States
# 6            Room in hotel    NaN  Las Vegas, Nevada, United States
# 7              Entire home   5.00  Las Vegas, Nevada, United States
# 8            Room in hotel    NaN  Las Vegas, Nevada, United States
# 9            Room in hotel    NaN  Las Vegas, Nevada, United States
# 10           Room in hotel    NaN  Las Vegas, Nevada, United States
# 11  Private room in resort    NaN  Las Vegas, Nevada, United States
# 12           Room in hotel    NaN  Las Vegas, Nevada, United States
#
#     numberOfGuests primaryHost/smartName  \
# 2                4            Aaron&Tina
# 3                6            Aaron&Tina
# ...
